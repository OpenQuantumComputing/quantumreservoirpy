# %%
import numpy as np
import matplotlib.pyplot as plt
from qreservoirpy import QReservoir, Layers, utilities


from qiskit.quantum_info import random_unitary
from qiskit_aer import AerSimulator
backend = AerSimulator(method="statevector")

from qiskit.circuit.library.standard_gates import HGate, SGate, CXGate

import tikzplotlib

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Initialization

# %%
n_qubits = 4
SHOTS = 10000
timeseries = [0, 1, 1, 2, 1, 1, 2] * 5
encoder = {
    0: '00',
    1: '01',
    2: '10',
    3: '11'
} 


OP = random_unitary(2**n_qubits)

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.linear_model import RidgeClassifier
from sklearn.neighbors import KNeighborsClassifier
models = np.array([
    SVC(kernel=ker, max_iter=1000) for ker in ['linear', 'poly', 'rbf', 'sigmoid']
] 
+ [
    RidgeClassifier(alpha=alph, max_iter=1000) for alph in np.linspace(0, 1e-3, 9)
] 
+ [
    KNeighborsClassifier(n_neighbors=n) for n in range(1, 10)
]
, dtype=object)

# %%
def build_method(circuit, timestep, encoding, reservoir):
    circuit.measure(range(2))
    circuit.initialize(encoding[timestep], range(2))
    circuit.unitary(reservoir, circuit.qubits)

qres = QReservoir(qubits=n_qubits, layers=[
    Layers.Reset(),
    Layers.Timeseries(build_method=build_method, 
                      encoding = encoder,
                      reservoir = OP)
])
fig = qres.circuit.draw('mpl')
# tikzplotlib.save("data/circuit_random.tex")

# %% [markdown]
# ## Running

# %%
states = qres.run(
    timeseries=timeseries, 
    shots=SHOTS,

)
# Out:
# Simulating: 100%|██████████| 1/1 [00:02<00:00,  2.30s/it]

# %%
# qres.circuit.draw('mpl')

# %%
WARMUP = 0.1 # 10%
warmup_idx = int(len(states) * WARMUP)

xstates = states[:-1][warmup_idx:]
target = timeseries[1:][warmup_idx:]
fig, ax = utilities.result_plotter(xstates, target)

# %%
cmap = plt.get_cmap('jet', len(np.unique(timeseries)))

plt.scatter(xstates[:, 0], xstates[:, 1], cmap=cmap, c=target)
# for i, x, y in zip(target, xstates[:, 2 * ii], xstates[:, 2 * ii + 1]):
#     ax.scatter(x, y,  color=cmap(i))

# ax.set_xlabel(f'state {2 * ii + 1}')
# ax.set_ylabel(f'state {2*(ii+1)}')
plt.xlabel("state 1")
plt.ylabel("state 2")
tikzplotlib.save("data/phase_random.tex")
# plt.show()

# %%
if xstates.shape[-1] >= 3:

    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')

    cmap = plt.get_cmap('jet', len(np.unique(timeseries)))
    for i, x, y, z in zip(target, xstates[:, 0], xstates[:, 1], xstates[:, 2]):
        ax.scatter(x, y, z, color=cmap(i))
    ax.set_xlabel('state 1')
    ax.set_ylabel('state 2')
    ax.set_zlabel('state 3')

# %% [markdown]
# ## Training

# %%
results = utilities.stress_test_models(xstates, target, models, test_to_train_ratio=1/3)
sorting = np.flip(np.argsort(results))
for model, res in zip(models[sorting], results[sorting]):
    print(f'Score of {model}: {res}')
    

model = models[sorting][0]
# Out:
# Score of KNeighborsClassifier(n_neighbors=1): 0.8918181818181807
# Score of KNeighborsClassifier(n_neighbors=3): 0.8199999999999998
# Score of KNeighborsClassifier(n_neighbors=2): 0.8090909090909086
# Score of KNeighborsClassifier(n_neighbors=4): 0.7281818181818178
# Score of RidgeClassifier(alpha=0.001, max_iter=1000): 0.6809090909090905
# Score of RidgeClassifier(alpha=0.000625, max_iter=1000): 0.6799999999999997
# Score of RidgeClassifier(alpha=0.0005, max_iter=1000): 0.6799999999999997
# Score of RidgeClassifier(alpha=0.000375, max_iter=1000): 0.6799999999999996
# Score of RidgeClassifier(alpha=0.00075, max_iter=1000): 0.6790909090909086
# Score of RidgeClassifier(alpha=0.00025, max_iter=1000): 0.6790909090909086
# Score of RidgeClassifier(alpha=0.000875, max_iter=1000): 0.6781818181818177
# Score of RidgeClassifier(alpha=0.000125, max_iter=1000): 0.676363636363636
# Score of RidgeClassifier(alpha=0.0, max_iter=1000): 0.6727272727272723
# Score of KNeighborsClassifier(): 0.6472727272727269
# Score of SVC(kernel='sigmoid', max_iter=1000): 0.5899999999999994
# Score of SVC(kernel='linear', max_iter=1000): 0.5899999999999994
# Score of KNeighborsClassifier(n_neighbors=6): 0.587272727272727
# Score of KNeighborsClassifier(n_neighbors=7): 0.5663636363636363
# Score of SVC(max_iter=1000): 0.557272727272727
# Score of SVC(kernel='poly', max_iter=1000): 0.557272727272727
# Score of KNeighborsClassifier(n_neighbors=8): 0.5554545454545451
# Score of KNeighborsClassifier(n_neighbors=9): 0.5536363636363638

# %% [markdown]
# ## Predicting

# %%
predict_from = timeseries[-20:]
num_preds = 2


pred_states, preds = qres.predict(
    num_pred=num_preds,
    model=model,
    shots=SHOTS,
    from_series=predict_from,
    backend=backend
)
# Out:
# Predicting: 100%|██████████| 43/43 [00:02<00:00, 14.78it/s]

# %%
true_values = timeseries

pred_plot = np.append(predict_from[-num_preds:], preds)
true_plot = np.append(predict_from[-num_preds:], true_values)

minlen = min(len(pred_plot), len(true_plot))

plt.plot(pred_plot[:minlen], label="Predictions")
plt.vlines(num_preds - 1, ymin=np.min(target), ymax=np.max(target), colors='k', linestyles='dashed')
plt.plot(true_plot[:minlen], label="True timeseries")
plt.legend()

# %%
from tqdm import tqdm


NUM_EXP = 1000
exp_res = np.zeros((NUM_EXP, len(models)))

for i in tqdm(range(NUM_EXP), desc="Experiment"):


    OP = random_unitary(2**n_qubits)
    qres = QReservoir(qubits=n_qubits, layers=[
    Layers.Reset(),
    Layers.Timeseries(build_method=build_method, 
                      encoding = encoder,
                      reservoir = OP)
    ])

    states = qres.run(
        timeseries=timeseries, 
        shots=SHOTS,
        disable_status_bar=True,
        transpile=True,
        backend=backend
    )

    xstates = states[:-1][warmup_idx:]
    target = timeseries[1:][warmup_idx:]
    exp_res[i] = utilities.stress_test_models(xstates, target, models, test_to_train_ratio=1/3, N=50)
# Out:
# Experiment: 100%|██████████| 1000/1000 [2:08:41<00:00,  7.72s/it]

# %%
# np.save("data/random_LONGSIM", exp_res)

# %%
fig, axes = plt.subplots(ncols=3, nrows=3, sharex='col', sharey='row')
fig.suptitle("KNeighborsClassifier")
ii = 0
jj = 0

mod = KNeighborsClassifier(n_neighbors=2)
for idx, model in enumerate(models):
    if type(model) == KNeighborsClassifier:
        axes[ii][jj].hist(exp_res[:, idx], density=True)
        axes[ii][jj].legend([model.n_neighbors])
        ii += 1
        if ii >= len(axes):
            ii = 0
            jj += 1
# temp_res = exp_res[:, 0]
# _ = axes.hist(temp_res)

# %%
plt.figure()
plt.title("KNeighborsClassifier")
for idx, model in enumerate(models):
    if type(model) == KNeighborsClassifier and model.n_neighbors in range(1, 4):
        plt.xlim([0.5, 1])
        plt.hist(exp_res[:, idx], density=True, label=model.n_neighbors, alpha=0.7, bins=50)
        ii += 1
        if ii >= len(axes):
            ii = 0
            jj += 1
plt.legend()
plt.xlabel("Score")
plt.ylabel("Probability density")
# tikzplotlib.save("data/random_KNeighbors.tex")

# %%
fig, axes = plt.subplots(ncols=4, nrows=3)
fig.suptitle("RidgeClassifier")
ii = 0
jj = 0

for idx, model in enumerate(models):
    if type(model) == RidgeClassifier:
        # axes[ii][jj].set_xlim([0, 1])
        axes[ii][jj].hist(exp_res[:, idx], density=True)
        axes[ii][jj].legend([round(model.alpha * 1e4, 1)])
        ii += 1
        if ii >= len(axes):
            ii = 0
            jj += 1

# %%
# fig, axes = plt.subplots(ncols=2, nrows=2)
# fig.suptitle("SVC")
# ii = 0
# jj = 0
plt.figure()
plt.title("SVC")
# plt.xlim([0, 1])

for idx, model in enumerate(models):
    if type(model) == SVC:
        plt.xlim([0.3, 1])
        plt.hist(exp_res[:, idx], density=True, label=model.kernel, alpha=0.7, bins=70)
        ii += 1
        if ii >= len(axes):
            ii = 0
            jj += 1
plt.legend()
plt.xlabel("Score")
plt.ylabel("Probability density")
# tikzplotlib.save("data/random_SVC.tex")

# %%
fig, ax = plt.subplots(ncols=2, nrows=1, sharey=True)

BINS = 30
ax[0].set_title("KNeighborsClassifier")
for idx, model in enumerate(models):
    if type(model) == KNeighborsClassifier and model.n_neighbors in [1, 2, 3]:
        ax[0].set_xlim([0.2, 1])
        ax[0].hist(exp_res[:, idx], density=True, label=model.n_neighbors, alpha=0.7, bins=BINS)
        ii += 1
        if ii >= len(axes):
            ii = 0
            jj += 1

ax[0].legend()
ax[0].set_xlabel("Score")
ax[0].set_ylabel("Probability density")

ax[1].set_title("SVC")

for idx, model in enumerate(models):
    if type(model) == SVC:
        ax[1].set_xlim([0.2, 1])
        ax[1].hist(exp_res[:, idx], density=True, label=model.kernel, alpha=0.7, bins=BINS)
        ii += 1
        if ii >= len(axes):
            ii = 0
            jj += 1
ax[1].legend()
ax[1].set_xlabel("Score")

# tikzplotlib.save("data/random_BOTH.tex")
