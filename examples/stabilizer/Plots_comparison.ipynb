# %%
import numpy as np
import matplotlib.pyplot as plt
# import matplotlib.colors as mcolors
import pickle

def tikzplotlib_fix_ncols(obj):
    """
    workaround for matplotlib 3.6 renamed legend's _ncol to _ncols, which breaks tikzplotlib
    """
    if hasattr(obj, "_ncols"):
        obj._ncol = obj._ncols
    for child in obj.get_children():
        tikzplotlib_fix_ncols(child)
casename="henon"

# %%
if casename=="logistic":
    from reservoirpy.datasets import logistic_map
    ts=logistic_map(100000, r=3.9, x0=0.5).flatten()
elif casename=="henon":
    from run_reservoir import henon1d   
    ts = henon1d(10000)

# %%
num_qubits=3
num_meas=2
degree=1
num_reservoirs=5
method="quantum_stab"
timeplex=10

tableaunr=1
noise=None
casename="logistic"  # "logistic" or "henon"

# %%
def get_data(ep, num_qubits, num_meas,num_reservoirs, method, casename, timeplex, degree, tableaunr, noise, decode=True):


    string_identifier=str(ep)+"_casename"+str(casename)+"_num_qubits"+str(num_qubits)+"_num_meas"+str(num_meas)
    string_identifier+="_degree"+str(degree)+"_num_reservoirs"+str(num_reservoirs)+"_timeplex"+str(timeplex)
    string_identifier+="_method"+str(method)+"_noise"+str(noise)+"_tableaunr"+str(tableaunr)+"_shots"+str(shots)
    if not decode:
        string_identifier+="_decodeFalse"
    string_identifier+=".pickle"
    name="results/X_train"+string_identifier
    print("name=",name)
    with open(name,"rb") as f:
        X_train = pickle.load(f)
    
    name="results/X_test"+string_identifier
    with open(name,"rb") as f:
        X_test = pickle.load(f)
    
    name="results/score"+string_identifier
    with open(name,"rb") as f:
        score = pickle.load(f)
        
    name="results/prediction"+string_identifier
    with open(name,"rb") as f:
        prediction = pickle.load(f)
        
    name="results/state"+string_identifier
    with open(name,"rb") as f:
        state = pickle.load(f)
    return X_train, X_test, score, prediction, state, string_identifier

# %%
X_train_class, X_test_class, score_class, prediction_class, state_class, basen_class = get_data(1, num_qubits, num_meas,num_reservoirs, "classical", casename, timeplex, degree, tableaunr, noise, decode=True)
X_train_part, X_test_part, score_part, prediction_part, state_part, basen_part = get_data(1, num_qubits, num_meas,num_reservoirs, "quantum_part", casename, timeplex, degree, tableaunr, noise, decode=True)
X_train_stab, X_test_stab, score_stab, prediction_stab, state_stab, basen_stab = get_data(1, num_qubits, num_meas,num_reservoirs, "quantum_stab", casename, timeplex, degree, tableaunr, noise, decode=True)
# Out:
# name= results/X_train1_casenamelogistic_num_qubits3_num_meas2_degree1_num_reservoirs5_timeplex10_methodclassical_noiseNone_tableaunr1.pickle
# name= results/X_train1_casenamelogistic_num_qubits3_num_meas2_degree1_num_reservoirs5_timeplex10_methodquantum_part_noiseNone_tableaunr1.pickle
# name= results/X_train1_casenamelogistic_num_qubits3_num_meas2_degree1_num_reservoirs5_timeplex10_methodquantum_stab_noiseNone_tableaunr1.pickle

# %%
fig=plt.figure(figsize=(20,5))
plt.plot(prediction_class, 'o-', label=r"classical")
plt.plot(prediction_part, 'o-', label=r"quantum part")
plt.plot(prediction_stab, 'o-', label=r"quantum stab")
plt.plot(np.concatenate([X_train_part,X_test_part]))
plt.axvline(x=len(X_train_part), color='k', linestyle='--', label='train/test split')
plt.legend(loc="lower left")
if casename=="logistic":
    plt.ylim([-0,1.1])
elif casename=="henon":
    plt.ylim([-1.5,1.5])

# %% [markdown]
# Plot convergence with training

# %%
plt.plot(state_part)
# Out:
# [<matplotlib.lines.Line2D at 0x2c117f60650>,
#  <matplotlib.lines.Line2D at 0x2c117f60050>,
#  <matplotlib.lines.Line2D at 0x2c117c01d50>,
#  <matplotlib.lines.Line2D at 0x2c117f609d0>,
#  <matplotlib.lines.Line2D at 0x2c117f62090>,
#  <matplotlib.lines.Line2D at 0x2c117ef0fd0>,
#  <matplotlib.lines.Line2D at 0x2c117f629d0>,
#  <matplotlib.lines.Line2D at 0x2c117f623d0>,
#  <matplotlib.lines.Line2D at 0x2c117f63dd0>,
#  <matplotlib.lines.Line2D at 0x2c119276250>]

# %%
plt.plot(state_stab)
# Out:
# [<matplotlib.lines.Line2D at 0x2c1183fe7d0>,
#  <matplotlib.lines.Line2D at 0x2c1183ffd90>,
#  <matplotlib.lines.Line2D at 0x2c1183ff990>,
#  <matplotlib.lines.Line2D at 0x2c1183ff4d0>,
#  <matplotlib.lines.Line2D at 0x2c1183fd050>,
#  <matplotlib.lines.Line2D at 0x2c1183ff010>,
#  <matplotlib.lines.Line2D at 0x2c1183feb10>,
#  <matplotlib.lines.Line2D at 0x2c117b2ccd0>,
#  <matplotlib.lines.Line2D at 0x2c119277ed0>,
#  <matplotlib.lines.Line2D at 0x2c117f150d0>]

# %%
for ep in [0,1]:
    fig=plt.figure(figsize=(20,5))
    X_train_class, X_test_class, score_class, prediction_class, state_class, basen_class = get_data(ep, num_qubits, num_meas,num_reservoirs, "classical", casename, timeplex, degree, tableaunr, noise, decode=True)
    X_train_part, X_test_part, score_part, prediction_part, state_part, basen_part = get_data(ep, num_qubits, num_meas,num_reservoirs, "quantum_part", casename, timeplex, degree, tableaunr, noise, decode=True)
    X_train_stab, X_test_stab, score_stab, prediction_stab, state_stab, basen_stab = get_data(ep, num_qubits, num_meas,num_reservoirs, "quantum_stab", casename, timeplex, degree, tableaunr, noise, decode=True)
    plt.plot(prediction_part, 'o-', label=r"quantum part")
    plt.plot(prediction_stab, 'o-', label=r"quantum stab")
    plt.plot(prediction_class, 'o-', label=r"classical")
    plt.plot(np.concatenate([X_train_part,X_test_part]),label=r"True signal")
    plt.axvline(x=len(X_train_part), color='k', linestyle='--', label='train/test split')
    plt.legend(loc="lower left")
    if casename=="logistic":
        plt.ylim([-0,1.1])
    elif casename=="henon":
        plt.ylim([-1.5,1.5])
    # plt.xlim([-1,len(prediction)])
    # plt.fill_between(range(len(X_train)), -2, 2, color='gray', alpha=0.5)
# Out:
# name= results/X_train0_casenamelogistic_num_qubits3_num_meas2_degree1_num_reservoirs5_timeplex10_methodclassical_noiseNone_tableaunr1.pickle
# name= results/X_train0_casenamelogistic_num_qubits3_num_meas2_degree1_num_reservoirs5_timeplex10_methodquantum_part_noiseNone_tableaunr1.pickle
# name= results/X_train0_casenamelogistic_num_qubits3_num_meas2_degree1_num_reservoirs5_timeplex10_methodquantum_stab_noiseNone_tableaunr1.pickle
# name= results/X_train1_casenamelogistic_num_qubits3_num_meas2_degree1_num_reservoirs5_timeplex10_methodclassical_noiseNone_tableaunr1.pickle
# name= results/X_train1_casenamelogistic_num_qubits3_num_meas2_degree1_num_reservoirs5_timeplex10_methodquantum_part_noiseNone_tableaunr1.pickle
# name= results/X_train1_casenamelogistic_num_qubits3_num_meas2_degree1_num_reservoirs5_timeplex10_methodquantum_stab_noiseNone_tableaunr1.pickle

# %%
k=1

# for ep in range(5):
for ep in [0,1]:
    
    if casename=="logistic":
        fig=plt.figure()
        plt.plot(ts[k:],ts[:-k],lw=0, color="grey", marker='o', alpha=.5)
    elif casename=="henon":
        fig = plt.figure()
        ax = fig.add_subplot(projection='3d')
        _=ax.scatter(ts[2:], ts[1:-1], ts[:-2],color="lightgray", s=2**5.5, alpha=.01)
    
    X_train_class, X_test_class, score_class, prediction_class, state_class, basen_class = get_data(ep, num_qubits, num_meas,num_reservoirs, "classical", casename, timeplex, degree, tableaunr, noise, decode=True)
    X_train_part, X_test_part, score_part, prediction_part, state_part, basen_part = get_data(ep, num_qubits, num_meas,num_reservoirs, "quantum_part", casename, timeplex, degree, tableaunr, noise, decode=True)
    X_train_stab, X_test_stab, score_stab, prediction_stab, state_stab, basen_stab = get_data(ep, num_qubits, num_meas,num_reservoirs, "quantum_stab", casename, timeplex, degree, tableaunr, noise, decode=True)
    tmp_class=prediction_class[len(X_train_class):]
    tmp_stab=prediction_stab[len(X_train_stab):]
    tmp_part=prediction_part[len(X_train_part):]
    if casename=="logistic":
        plt.plot(2*tmp_class[k:]-1, 2*tmp_class[:-k]-1,'o', label=r"classical")
        plt.plot(2*tmp_stab[k:]-1, 2*tmp_stab[:-k]-1,'o', label=r"quantum stab")
        plt.plot(2*tmp_part[k:]-1, 2*tmp_part[:-k]-1,'o', label=r"quantum part")
    elif casename=="henon":
        _=ax.scatter(tmp_class[2:], tmp_class[1:-1], tmp_class[:-2], marker='s', s=2**5.5, label=r"classical", color="blue")
        _=ax.scatter(tmp_stab[2:], tmp_stab[1:-1], tmp_stab[:-2], marker='s', s=2**5.5, label=r"quantum stab", color="darkorange")
        _=ax.scatter(tmp_part[2:], tmp_part[1:-1], tmp_part[:-2], marker='s', s=2**5.5, label=r"quantum part", color="green")
    

        ax.set_xlim3d(-1,1)
        ax.set_ylim3d(-1,1)
        ax.set_zlim3d(-1,1)
        ax.set_xticks([-1, 1])
        ax.set_yticks([-1, 1])
        ax.set_zticks([-1, 1])
        ax.set_xlabel('$x_n$')
        ax.set_ylabel('$x_{n-1}$')
        ax.set_zlabel('$x_{n-2}$', rotation=90)
        ax.zaxis.labelpad=-5
# Out:
# name= results/X_train0_casenamelogistic_num_qubits3_num_meas2_degree1_num_reservoirs5_timeplex10_methodclassical_noiseNone_tableaunr1.pickle
# name= results/X_train0_casenamelogistic_num_qubits3_num_meas2_degree1_num_reservoirs5_timeplex10_methodquantum_part_noiseNone_tableaunr1.pickle
# name= results/X_train0_casenamelogistic_num_qubits3_num_meas2_degree1_num_reservoirs5_timeplex10_methodquantum_stab_noiseNone_tableaunr1.pickle
# name= results/X_train1_casenamelogistic_num_qubits3_num_meas2_degree1_num_reservoirs5_timeplex10_methodclassical_noiseNone_tableaunr1.pickle
# name= results/X_train1_casenamelogistic_num_qubits3_num_meas2_degree1_num_reservoirs5_timeplex10_methodquantum_part_noiseNone_tableaunr1.pickle
# name= results/X_train1_casenamelogistic_num_qubits3_num_meas2_degree1_num_reservoirs5_timeplex10_methodquantum_stab_noiseNone_tableaunr1.pickle

# %%
for ep in [0,1]:
    fig=plt.figure(figsize=(20,5))

    X_train, X_test, score, prediction, statec, basen =  X_train, X_test, score, prediction, state, basen = get_data(ep,  num_qubits, num_meas,num_reservoirs, method, casename, timeplex, degree, tableaunr, noise, decode=True)
    
    plt.plot(X_test,'k-', label='exact')
    
    plt.plot(prediction[len(X_train):], 'x-', label="classical")
    
    X_train, X_test, score, prediction, state, basen = get_data(ep, 4, 2, "quantum_part", "None")
    plt.plot(prediction[len(X_train):], 'o-', label=r"quantum $\langle Z_1, Z_2, Z_3\rangle$")
    print(state.shape,X_train.shape)
    
    X_train, X_test, score, prediction, state, basen = get_data(ep, 4, 2, "quantum_stab", "None")
    plt.plot(prediction[len(X_train):], 'o-', label=r"quantum $\langle Z_1Z_2, Z_2Z_3, Z_3Z_4\rangle$")
    
    # plt.plot(ts[15:prediction[ty].shape[0]],label='ground truth')
    # plt.plot(np.concatenate([X_train,X_test]))
    # plt.plot(X_test)
    plt.legend(loc="lower left")
    if casename=="logistic":
        plt.ylim([-0,1.1])
    elif casename=="henon":
        plt.ylim([-1.5,1.5])
    # plt.xlim([-1,len(prediction)])
    # plt.fill_between(range(len(X_train)), -2, 2, color='gray', alpha=0.5)
    
    # plt.show()
    fig=tikzplotlib_fix_ncols(fig)
    tikzplotlib.save("convergence_ep"+str(ep)+"_"+basen+".tex")
# Out:
# name= results/X_train0_casenamelogistic_num_qubits3_num_meas2_degree1_num_reservoirs5_timeplex10_methodquantum_stab_noiseNone_tableaunr1.pickle
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[135], line 10
#       6 plt.plot(X_test,'k-', label='exact')
#       8 plt.plot(prediction[len(X_train):], 'x-', label="classical")
# ---> 10 X_train, X_test, score, prediction, state, basen = get_data(ep, 4, 2, "quantum_part", "None")
#      11 plt.plot(prediction[len(X_train):], 'o-', label=r"quantum $\langle Z_1, Z_2, Z_3\rangle$")
#      12 print(state.shape,X_train.shape)
#
# TypeError: get_data() missing 5 required positional arguments: 'casename', 'timeplex', 'degree', 'tableaunr', and 'noise'

# %%
# for ep in range(5):
#     X_train, X_test, score, prediction, state, basen = get_data(ep, 4, 3, "quantum_stab", "None")
#     tmp=prediction[len(X_train):]
#     # plt.plot(tmp)
#     # plt.plot(X_test)
#     # np.cov(tmp, X_test)
#     print("C",ep,"=",np.cov(tmp, X_test)[0][1]**2/(np.var(tmp) * np.var(X_test)))
# # plt.plot(tmp)
# # plt.plot(X_test)

# %%
# fig=plt.figure(figsize=(20,5))

# ep=4

# X_train, X_test, score, prediction, state, basen = get_data(ep, 7, 6, "classical", "None")
# gt=np.concatenate([X_train,X_test])
# plt.plot((prediction-gt)**2, 'x-', label="classical")

# X_train, X_test, score, prediction, state, basen = get_data(ep, 3, 2, "quantum_part", "None")
# plt.plot((prediction-gt)**2, 'o-', label="quantum part")

# X_train, X_test, score, prediction, state, basen = get_data(ep, 3, 2, "quantum_stab", "None")
# plt.plot((prediction-gt)**2, 'o-', label="quantum stab")

# X_train, X_test, score, prediction, state, basen = get_data(ep, 3, 2, "quantum_part", "True")
# plt.plot((prediction-gt)**2, 'o-', label="quantum part, depolarizing")

# X_train, X_test, score, prediction, state, basen = get_data(ep, 3, 2, "quantum_stab", "True")
# plt.plot((prediction-gt)**2, 'o-', label="quantum stab, depolarizing")

# # plt.plot(ts[15:prediction[ty].shape[0]],label='ground truth')
# plt.plot()
# plt.legend()
# plt.ylim([-0,1.1])
# plt.xlim([-1,len(prediction)])
# plt.fill_between(range(len(X_train)), -2, 2, color='gray', alpha=0.5)

# # plt.show()
# fig=tikzplotlib_fix_ncols(fig)
# tikzplotlib.save("comparison2_"+basen+".tex")

# %%
k=1

# for ep in range(5):
for ep in [0,4]:

    if casename=="logistic":
        fig=plt.figure()
        plt.plot(ts[k:],ts[:-k],lw=0, color="gray", marker='o', alpha=.5)
    elif casename=="henon":
        fig = plt.figure()
        ax = fig.add_subplot(projection='3d')
        _=ax.scatter(ts[2:], ts[1:-1], ts[:-2],color="lightgray", s=2**5.5, alpha=.01)
    
    
    # X_train, X_test, score, prediction, state, basen = get_data(ep, 4, 3, "classical", "None")
    # tmp=prediction[len(X_train):]
    # plt.plot(tmp[k:], tmp[:-k],'s', label="classical")
    
    X_train, X_test, score, prediction, state, basen = get_data(ep, 4, 2, "quantum_part", "None")
    tmp=prediction[len(X_train):]
    if casename=="logistic":
        plt.plot(tmp[k:], tmp[:-k],'o', label=r"quantum $\langle Z_1, Z_2, Z_3\rangle$")
    elif casename=="henon":
        _=ax.scatter(tmp[2:], tmp[1:-1], tmp[:-2], marker='s', s=2**5.5, label=r"quantum $\langle Z_1, Z_2\rangle$", color="darkorange")
    
    X_train, X_test, score, prediction, state, basen = get_data(ep, 4, 2, "quantum_stab", "None")
    tmp=prediction[len(X_train):]
    if casename=="logistic":
        plt.plot(tmp[k:], tmp[:-k],'*', label=r"quantum $\langle Z_1Z_2, Z_2Z_3, Z_3Z_4\rangle$")
    elif casename=="henon":
        _=ax.scatter(tmp[2:], tmp[1:-1], tmp[:-2], alpha=1, marker='^', s=2**5.5, label=r"quantum $\langle Z_1Z_2, Z_2Z_3\rangle$", color="forestgreen")
    
    # RADIUS = 2.0  # Control this value.
    # ax.set_xlim3d(-RADIUS / 2, RADIUS / 2)
    # ax.set_zlim3d(-RADIUS / 2, RADIUS / 2)
    # ax.set_ylim3d(-RADIUS / 2, RADIUS / 2)
    ax.set_xlim3d(-1,1)
    ax.set_ylim3d(-1,1)
    ax.set_zlim3d(-1,1)
    ax.set_xticks([-1, 1])
    ax.set_yticks([-1, 1])
    ax.set_zticks([-1, 1])
    ax.set_xlabel('$x_n$')
    ax.set_ylabel('$x_{n-1}$')
    ax.set_zlabel('$x_{n-2}$', rotation=90)
    ax.zaxis.labelpad=-5
    # X_train, X_test, score, prediction, state, basen = get_data(ep, 3, 2, "quantum_part", "True")
    # tmp=prediction[len(X_train):]
    # plt.plot(tmp[k:], tmp[:-k],'o', color='lightgreen', label="quantum part, depolarizing")
    
    # X_train, X_test, score, prediction, state, basen = get_data(ep, 3, 2, "quantum_stab", "True")
    # tmp=prediction[len(X_train):]
    # plt.plot(tmp[k:], tmp[:-k],'*', color="lightblue", label="quantum stab, depolarizing")
    
    
    # plt.ylim([0,1])
    # plt.xlim([0,1])
    # plt.legend(loc='upper left')
    
    # fig=tikzplotlib_fix_ncols(fig)
    # tikzplotlib.save("convergence2_ep"+str(ep)+"_"+basen+".tex")

# X_train, X_test, score, prediction, state, basen = get_data(ep, 3, 2, "quantum_part", "None")
# tmp=prediction[len(X_train):]
# plt.plot(tmp[1:], tmp[:-1],'or')

# %% [markdown]
# Plot noise vs. noise free

# %%
k=1

# for ep in range(5):
for ep in [0,4]:
    fig=plt.figure()
    
    plt.plot(ts[k:],ts[:-k],lw=0, color="gray", marker='o', alpha=.5)

    X_train, X_test, score, prediction, state, basen = get_data(ep, 4, 3, "quantum_stab", "None")
    tmp=prediction[len(X_train):]
    plt.plot(tmp[k:], tmp[:-k],'o', label="ideal")
    
    # X_train, X_test, score, prediction, state, basen = get_data(ep, 4, 3, "quantum_stab", "True")
    # tmp=prediction[len(X_train):]
    # plt.plot(tmp[k:], tmp[:-k],'*', label=r"quantum $\langle Z_1Z_2, Z_2Z_3, Z_3Z_4\rangle$")
    
    
    # X_train, X_test, score, prediction, state, basen = get_data(ep, 4, 3, "quantum_part", "True")
    # tmp=prediction[len(X_train):]
    # plt.plot(tmp[k:], tmp[:-k],'o', label="depolarizing part")
    
    X_train, X_test, score, prediction, state, basen = get_data(ep, 4, 3, "quantum_stab", "True")
    tmp=prediction[len(X_train):]
    plt.plot(tmp[k:], tmp[:-k],'o', label="depolarizing stab")
    
    
    # plt.ylim([0,1])
    # plt.xlim([0,1])
    plt.legend(loc='center left')
    
    # fig=tikzplotlib_fix_ncols(fig)
    # tikzplotlib.save("noise_ep"+str(ep)+"_"+basen+".tex")

# X_train, X_test, score, prediction, state, basen = get_data(ep, 3, 2, "quantum_part", "None")
# tmp=prediction[len(X_train):]
# plt.plot(tmp[1:], tmp[:-1],'or')

# %% [markdown]
# Plot that it does not work without the correction step

# %%
k=1

# for ep in range(5):
for ep in [4]:
    fig=plt.figure()
    
    plt.plot(ts[k:],ts[:-k],lw=0, color="gray", marker='o', alpha=.5)
    
    X_train, X_test, score, prediction, state, basen = get_data(ep, 4, 3, "quantum_stab", "None", decode=False)
    tmp=prediction[len(X_train):]
    plt.plot(tmp[k:], tmp[:-k],'*', color="darkblue", label="no correction", markersize = 10)
    
    
    X_train, X_test, score, prediction, state, basen = get_data(ep, 4, 3, "quantum_stab", "None")
    tmp=prediction[len(X_train):]
    plt.plot(tmp[k:], tmp[:-k],'*', color="lightblue", label="with correction", markersize = 10)
    
    
    # plt.ylim([0,1])
    # plt.xlim([0,1])
    plt.legend(loc='center left')
    
    # fig=tikzplotlib_fix_ncols(fig)
    # tikzplotlib.save("effect_of_correction_ep"+str(ep)+"_"+basen+".tex")

# X_train, X_test, score, prediction, state, basen = get_data(ep, 3, 2, "quantum_part", "None")
# tmp=prediction[len(X_train):]
# plt.plot(tmp[1:], tmp[:-1],'or')

# %%
fig=plt.figure(figsize=(20,5))

ep=4

X_train, X_test, score, prediction, state, basen = get_data(ep, 4, 3, "quantum_stab", "None", decode=False)
plt.plot(prediction, 'o-',color="darkblue", label="no correction")
  
    
X_train, X_test, score, prediction, state, basen = get_data(ep, 4, 3, "quantum_stab", "None")
plt.plot(prediction, 'o-', color="lightblue", label="with correction")

# plt.plot(ts[15:prediction[ty].shape[0]],label='ground truth')
plt.plot()
plt.legend()
plt.ylim([-0,1.1])
plt.xlim([-1,len(prediction)])
plt.fill_between(range(len(X_train)), -2, 2, color='gray', alpha=0.5)

# plt.show()
# fig=tikzplotlib_fix_ncols(fig)
# tikzplotlib.save("effect_of_correction2_ep"+str(ep)+"_"+basen+".tex")

# %% [markdown]
# Different number of qubits and measurements

# %%
k=1

# for ep in range(5):
for ep in [4]:
    fig=plt.figure()
    
    plt.plot(ts[k:],ts[:-k],lw=0, color="gray", marker='o', alpha=.5)
    
    X_train, X_test, score, prediction, state, basen = get_data(ep, 3, 2, "quantum_part", "True")
    tmp=prediction[len(X_train):]
    plt.plot(tmp[k:], tmp[:-k],'o', label=r"3 qubits $\langle Z_1, Z_2\rangle$")
    
    X_train, X_test, score, prediction, state, basen = get_data(ep, 4, 2, "quantum_part", "True")
    tmp=prediction[len(X_train):]
    plt.plot(tmp[k:], tmp[:-k],'o', label=r"4 qubits $\langle Z_1, Z_2\rangle$")
    
    X_train, X_test, score, prediction, state, basen = get_data(ep, 4, 3, "quantum_part", "True")
    tmp=prediction[len(X_train):]
    plt.plot(tmp[k:], tmp[:-k],'o', label=r"4 qubits $\langle Z_1, Z_2, Z_3\rangle$")
    
    X_train, X_test, score, prediction, state, basen = get_data(ep, 7, 4, "quantum_part", "True")
    tmp=prediction[len(X_train):]
    plt.plot(tmp[k:], tmp[:-k],'o', label=r"7 qubits $\langle Z_1, \cdots, Z_4 \rangle$")
    
    X_train, X_test, score, prediction, state, basen = get_data(ep, 7, 6, "quantum_part", "True")
    tmp=prediction[len(X_train):]
    plt.plot(tmp[k:], tmp[:-k],'o', label=r"7 qubits $\langle Z_1, \cdots, Z_6 \rangle$")
    
    # X_train, X_test, score, prediction, state, basen = get_data(ep, 4, 3, "quantum_stab", "True")
    # tmp=prediction[len(X_train):]
    # plt.plot(tmp[k:], tmp[:-k],'*', label=r"quantum $\langle Z_1Z_2, Z_2Z_3, Z_3Z_4\rangle$")
    
    
    # X_train, X_test, score, prediction, state, basen = get_data(ep, 3, 2, "quantum_part", "True")
    # tmp=prediction[len(X_train):]
    # plt.plot(tmp[k:], tmp[:-k],'o', color='lightgreen', label="quantum part, depolarizing")
    
    # X_train, X_test, score, prediction, state, basen = get_data(ep, 3, 2, "quantum_stab", "True")
    # tmp=prediction[len(X_train):]
    # plt.plot(tmp[k:], tmp[:-k],'*', color="lightblue", label="quantum stab, depolarizing")
    
    
    # plt.ylim([0,1])
    # plt.xlim([0,1])
    plt.legend(loc='center left')
    
    fig=tikzplotlib_fix_ncols(fig)
    tikzplotlib.save("comparison_numqubits_ep"+str(ep)+"_"+basen+".tex")
    break

# X_train, X_test, score, prediction, state, basen = get_data(ep, 3, 2, "quantum_part", "None")
# tmp=prediction[len(X_train):]
# plt.plot(tmp[1:], tmp[:-1],'or')

# %%
k=1

# for ep in range(5):
for ep in [2]:
    fig=plt.figure()
    
    plt.plot(ts[k:],ts[:-k],lw=0, color="gray", marker='o', alpha=.5)
    
    X_train, X_test, score, prediction, state, basen = get_data(ep, 3, 2, "quantum_stab", "True")
    tmp=prediction[len(X_train):]
    plt.plot(tmp[k:], tmp[:-k],'o', label=r"3 qubits $\langle Z_1Z_2, Z_2Z_3\rangle$")
    
    X_train, X_test, score, prediction, state, basen = get_data(ep, 4, 2, "quantum_stab", "True")
    tmp=prediction[len(X_train):]
    plt.plot(tmp[k:], tmp[:-k],'o', label=r"4 qubits $\langle Z_1Z_2, Z_2Z_3\rangle$")
    
    X_train, X_test, score, prediction, state, basen = get_data(ep, 4, 3, "quantum_stab", "True")
    tmp=prediction[len(X_train):]
    plt.plot(tmp[k:], tmp[:-k],'o', label=r"4 qubits $\langle Z_1Z_2, \cdots, Z_3Z_4\rangle$")
    
    X_train, X_test, score, prediction, state, basen = get_data(ep, 7, 4, "quantum_stab", "True")
    tmp=prediction[len(X_train):]
    plt.plot(tmp[k:], tmp[:-k],'o', label=r"7 qubits $\langle Z_1Z_2, \cdots, Z_4Z_5 \rangle$")
    
    X_train, X_test, score, prediction, state, basen = get_data(ep, 7, 6, "quantum_stab", "True")
    tmp=prediction[len(X_train):]
    plt.plot(tmp[k:], tmp[:-k],'o', label=r"7 qubits $\langle Z_1Z_2, \cdots, Z_6Z_7 \rangle$")
    
    # X_train, X_test, score, prediction, state, basen = get_data(ep, 4, 3, "quantum_stab", "True")
    # tmp=prediction[len(X_train):]
    # plt.plot(tmp[k:], tmp[:-k],'*', label=r"quantum $\langle Z_1Z_2, Z_2Z_3, Z_3Z_4\rangle$")
    
    
    # X_train, X_test, score, prediction, state, basen = get_data(ep, 3, 2, "quantum_part", "True")
    # tmp=prediction[len(X_train):]
    # plt.plot(tmp[k:], tmp[:-k],'o', color='lightgreen', label="quantum part, depolarizing")
    
    # X_train, X_test, score, prediction, state, basen = get_data(ep, 3, 2, "quantum_stab", "True")
    # tmp=prediction[len(X_train):]
    # plt.plot(tmp[k:], tmp[:-k],'*', color="lightblue", label="quantum stab, depolarizing")
    
    
    # plt.ylim([0,1])
    # plt.xlim([0,1])
    plt.legend(loc='center left')
    
    fig=tikzplotlib_fix_ncols(fig)
    tikzplotlib.save("comparison_numqubits_ep"+str(ep)+"_"+basen+".tex")
    break

# X_train, X_test, score, prediction, state, basen = get_data(ep, 3, 2, "quantum_part", "None")
# tmp=prediction[len(X_train):]
# plt.plot(tmp[1:], tmp[:-1],'or')

# %%
def limitrange(topology, dist=2):
    nh = []
    for tmp in topology:
        if abs(tmp[0]-tmp[1])<=2:
            nh.append(tmp)
    return nh

# %%
from itertools import combinations
h=list(combinations(range(7), 2))
nh=limitrange(h)
print(nh)
len(h), len(nh)
